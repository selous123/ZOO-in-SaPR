# %%
simo_score = [
[[2.6337,0.0290],[2.6623,0.0910],[3.4055,0.1526],[3.4603,0.0780],[4.4344,0.2510]],
[[4.5724,0.0447],[4.6342,0.1044],[5.2738,0.1356],[5.0364,0.1350],[6.0301,0.1875]],
[[4.5724,0.0447],[4.6342,0.1045],[5.2737,0.1357],[5.0364,0.1350],[6.0301,0.1875]],
[[4.5727,0.0476],[4.6383,0.1039],[5.2857,0.1297],[5.0399,0.1376],[6.0265,0.1960]],
[[4.5689,0.0476],[4.6331,0.1039],[5.2797,0.1290],[5.0329,0.1373],[6.0148,0.1960]],
[[4.6179,0.0594],[4.6811,0.2111],[5.7398,0.1872],[5.6670,0.2334],[6.5437,0.2477]]
]

import numpy as np
simo_score = np.array(simo_score)

print simo_score.shape

mean_simo_score = simo_score[:,:,0]
print mean_simo_score

x = np.arange(5)

print x

# %%
import seaborn as sns

sns.pointplot(x="sex", y="total_bill", hue="day",data=simo_score)

# %%
import pandas as pd
import matplotlib.pyplot as plt
simo_score = [
[[2.6337,0.0290],[2.6623,0.0910],[3.4055,0.1526],[3.4603,0.0780],[4.4344,0.2510]],
[[4.5724,0.0447],[4.6342,0.1044],[5.2738,0.1356],[5.0364,0.1350],[6.0301,0.1875]],
[[4.5724,0.0447],[4.6342,0.1045],[5.2737,0.1357],[5.0364,0.1350],[6.0301,0.1875]],
[[4.5727,0.0476],[4.6383,0.1039],[5.2857,0.1297],[5.0399,0.1376],[6.0265,0.1960]],
[[4.5689,0.0476],[4.6331,0.1039],[5.2797,0.1290],[5.0329,0.1373],[6.0148,0.1960]],
[[4.6179,0.0594],[4.6811,0.2111],[5.7398,0.1872],[5.6670,0.2334],[6.5437,0.2477]]
]

import numpy as np
simo_score = np.array(simo_score)

print simo_score.shape

mean_simo_score = simo_score[:,:,0]
mean_simo_score = mean_simo_score.T
print mean_simo_score
data = pd.DataFrame(mean_simo_score,index=[600,700,800,900,1000],columns=["simo","ols","hard","ridge","lasso","huber"])


import seaborn as sns
sns.set_style("whitegrid") 
ax = sns.pointplot(x=np.arange(5), y="simo",markers='x',data=data,linestyles=["-"])
ax = sns.pointplot(x=np.arange(5), y="ols",data=data+0.3)
ax = sns.pointplot(x=np.arange(5)+1, y="hard",data=data+0.2)
ax = sns.pointplot(x=np.arange(5), y="ridge",data=data+0.1,color="red")
ax = sns.pointplot(x=np.arange(5), y="lasso",data=data)
ax = sns.pointplot(x=np.arange(5), y="huber",data=data,linestyles=["--"])

plt.show()

# %%
import matplotlib.pyplot as plt
def plot_save_fig(data,x,y,xlabel,title,xticks,yticks,istitle,ax,legend_fontsize = 20,ncol=1,legend_label=False):
    
    

#     plt.figure(figsize=(6, 4.5))
    #ax = plt.gca()
    ax.spines['top'].set_visible(False) #去掉上边框
#     #ax.spines['bottom'].set_visible(False) #去掉下边框
#     #ax.spines['left'].set_visible(False) #去掉左边框
    ax.spines['right'].set_visible(False) #去掉右边框
    if legend_label:
        ax.plot(x,data[y[0]],linestyle="-", linewidth=1,marker="o",markersize=10,color="red",label="SZMO")
        ax.plot(x,data[y[1]],linestyle="-.", linewidth=1,marker="v",markersize=10,color="black",label="LR")
    #     #plt.plot(x,mean_simo_score[2],linestyle="--", linewidth=1)
    #     #plt.plot(x,mean_simo_score[3]+0.3,linestyle=":", linewidth=1)
    #     #plt.plot(x,mean_simo_score[4],linestyle="-.", linewidth=1)
        ax.plot(x,data[y[2]],linestyle="-", linewidth=1,marker="*",markersize=10,color="blue",label="HR")
    else:
        ax.plot(x,data[y[0]],linestyle="-", linewidth=1,marker="o",markersize=10,color="red")
        ax.plot(x,data[y[1]],linestyle="-.", linewidth=1,marker="v",markersize=10,color="black")
#     #plt.plot(x,mean_simo_score[2],linestyle="--", linewidth=1)
#     #plt.plot(x,mean_simo_score[3]+0.3,linestyle=":", linewidth=1)
#     #plt.plot(x,mean_simo_score[4],linestyle="-.", linewidth=1)
        ax.plot(x,data[y[2]],linestyle="-", linewidth=1,marker="*",markersize=10,color="blue")
    ax.set_ylabel(r"$||w-w^*||_2$")
    ax.set_xlabel(xlabel)
    
    ax.set_xticks(xticks)
    ax.set_yticks(yticks)

#     #plt.xticks([])
#     #plt.yticks([])

#     #plt.title(r"Fix n$=1500,\sigma=1,\alpha=0.5$")

#     #size = fig.get_size_inches()*fig.dpi # get fig size in pixels
    
    ax.tick_params(direction='in')
    #ax.legend(fontsize=legend_fontsize,ncol=ncol,fancybox=True, framealpha=0.5)
#     plt.tight_layout()
#     if istitle:
    ax.set_title(title, y=-0.45,fontweight='bold')
#     plt.savefig(name, format='eps', bbox_inches='tight', pad_inches = 0)
    #plt.show()

# %%
#draw samples
# simo_score = [
# [[2.6337,0.0290],[2.6623,0.0910],[3.4055,0.1526],[3.4603,0.0780],[4.4344,0.2510]],
# [[4.5724,0.0447],[4.6342,0.1044],[5.2738,0.1356],[5.0364,0.1350],[6.0301,0.1875]],
# [[4.5724,0.0447],[4.6342,0.1045],[5.2737,0.1357],[5.0364,0.1350],[6.0301,0.1875]],
# [[4.5727,0.0476],[4.6383,0.1039],[5.2857,0.1297],[5.0399,0.1376],[6.0265,0.1960]],
# [[4.5689,0.0476],[4.6331,0.1039],[5.2797,0.1290],[5.0329,0.1373],[6.0148,0.1960]],
# [[4.6179,0.0594],[4.6811,0.2111],[5.7398,0.1872],[5.6670,0.2334],[6.5437,0.2477]]
# ]
# import numpy as np
# simo_score = np.array(simo_score)
# print simo_score.shape
# mean_simo_score = simo_score[:,:,0]/10
# print mean_simo_score
# data = mean_simo_score


import numpy as np
def prepross_data(score):
    score = np.array(score)
    mean_simo_score = score[:,:,0]/10
    return mean_simo_score


import matplotlib
import matplotlib.pyplot as plt
#set rcParams
matplotlib.rc('axes',titlesize=25)
matplotlib.rc('axes', labelsize=25)
matplotlib.rc('xtick',labelsize=25)
matplotlib.rc('ytick',labelsize=25)
fig,axs = plt.subplots(1,4,figsize=(24,4.5),constrained_layout=True)
axs = axs.flatten()


m_score = [
[
0.9221 ,1.5236 ,1.5236 ,1.5231 ,1.6176 ,1.7768] ,
 [1.1912 ,1.8995 ,1.8995 ,1.9043 ,2.0698 ,2.2750] ,
  [1.7268 ,2.5091 ,2.5091 ,2.5137 ,2.7705 ,3.0142] ,
   [2.0689 ,2.9073 ,2.9073 ,2.9074 ,3.2390 ,3.4855] ,
    [2.7642 ,3.7370 ,3.7370 ,3.7447 ,4.1530 ,4.2868 ]
]
data = np.array(m_score)
data = data.T
x = [600,700,800,900,1000]
y = [0,1,5]
title=r'(b) Fix n=1500,$\sigma$=1,$\alpha$=0.5'
xticks=[600,800,1000]
yticks = [0.5,2.5,4.5]
#istitle=False
#name = "sample_notitle.png"
istitle=True

plot_save_fig(data,x,y,xlabel="m",title=title,xticks=xticks,yticks=yticks,istitle=istitle,ax=axs[1],legend_label=True)
#legend = plt.figlegend(fontsize=20,ncol=3,loc=9,bbox_to_anchor=(0.5, 1.1))


n_score = [
[1.1710, 1.7915, 1.7915, 1.7995, 1.9600, 2.2958 ],
[0.9303, 1.4907, 1.4906, 1.4916, 1.5911, 1.6487 ],
[0.7137, 1.2802, 1.2802, 1.2802, 1.3550, 1.2467 ],
[0.6480 ,1.2344, 1.2344, 1.2367, 1.3146, 1.1650],
[0.5735 ,1.0996 ,1.0996 ,1.1020 ,1.1852 ,1.0197 ]
]
data = np.array(n_score)
data = data.T
x = [1000,1200,1400,1600,1800]
y = [0,1,5]
title=r'(a) Fix m=500,$\sigma$=1,$\alpha$=0.5'
xticks=[1000,1400,1800]
yticks = [0.5,1.5,2.5]
#istitle=False
#name = "sample_notitle.png"
istitle=True
plot_save_fig(data,x,y,xlabel="n",title=title,xticks=xticks,yticks=yticks,istitle=istitle,ax=axs[0]) 


#sigma
sigma_score = [
[0.5915, 0.8958, 0.8958, 0.8977, 0.9585, 0.8972 ],
[0.7504, 1.0192, 1.0192, 1.0208, 1.0815, 1.0504 ],
[0.9182, 1.0903, 1.0903, 1.0931 ,1.1181, 1.1645 ],
[1.1122, 1.2704, 1.2704, 1.2721, 1.3256, 1.3434 ],
[1.2402, 1.3163, 1.3163, 1.3163, 1.3517, 1.4263 ]
]
data = np.array(sigma_score)
data = data.T
x = [2,3,4,5,6]
y = [0,1,5]
title=r'(c) Fix m=400,n=1800,$\alpha$=0.5'
xticks=[2,4,6]
yticks = [0.50,1.00,1.50]
#istitle=False
#name = "sample_notitle.png"
istitle=True
plot_save_fig(data,x,y,xlabel=r'$\sigma$',title=title,xticks=xticks,yticks=yticks,istitle=istitle,ax=axs[2],legend_fontsize = 14,ncol=3) 

#alpha
alpha_score = [
[0.5791 ,0.9992 ,0.9992 ,1.0008 ,1.0577 ,1.0101],
 [0.6589 ,1.0278 ,1.0278 ,1.0286 ,1.0807 ,1.1237 ],
  [0.7654 ,1.1200 ,1.1200 ,1.1209 ,1.1724 ,1.2507],
   [0.9116 ,1.1743 ,1.1743 ,1.1775 ,1.1972 ,1.3781 ],
    [1.0204 ,1.2025 ,1.2025 ,1.2028 ,1.2440 ,1.4678 ]
]

data = np.array(alpha_score)
data = data.T

#data = prepross_data(alpha_score)
x = [0.6,0.7,0.8,0.9,1.0]
y = [0,1,5]
title=r'(d) Fix m=400,n=1800,$\sigma$=1'
#yticks = [0.25,0.35,0.45,0.55,0.65,0.75]
xticks = [0.6,0.8,1.0]
yticks = [0.5,1.0,1.5]
#istitle=False
#name = "sample_notitle.png"
istitle=True
plot_save_fig(data,x,y,xlabel=r'$\alpha$',title=title,xticks=xticks,yticks=yticks,istitle=istitle,ax=axs[3]) 


name = "samples.pdf"
fig.tight_layout()
#fig.subplots_adjust(top=0.75)
plt.subplots_adjust(wspace=0.25, hspace=0)
#axs[0].autoscale_view()
#fig.artists.append(legend)
#legend = plt.figlegend(fontsize=20,ncol=3,loc=9,bbox_to_anchor=(0.5, 1.5))
legend = fig.legend(fontsize=25,ncol=3,loc=9,bbox_to_anchor=(0.5, 1.2))
fig.savefig(name,format='pdf', bbox_inches='tight', pad_inches = 0)

plt.show()

# %%
alpha_score = [
[0.5791 ,0.9992 ,0.9992 ,1.0008 ,1.0577 ,1.0101],
 [0.6589 ,1.0278 ,1.0278 ,1.0286 ,1.0807 ,1.1237 ],
  [0.7654 ,1.1200 ,1.1200 ,1.1209 ,1.1724 ,1.2507],
   [0.9116 ,1.1743 ,1.1743 ,1.1775 ,1.1972 ,1.3781 ],
    [1.0204 ,1.2025 ,1.2025 ,1.2028 ,1.2440 ,1.4678 ]
]

import numpy as np
def prepross_data(score):
    score = np.array(score)
    mean_simo_score = score/10
    return mean_simo_score
prepross_data(alpha_score)
print alpha_score

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0,2*np.pi)
colors=["#7aa0c4","#ca82e1" ,"#8bcd50","#e18882"]
fig, axes = plt.subplots(ncols=2)
for i in range(4):
    axes[i//2].plot(x,np.sin(x+i), color=colors[i],label="y=sin(x+{})".format(i))

fig.legend(loc=7)
fig.tight_layout()
fig.subplots_adjust(right=0.75)   
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('axes',titlesize=17)
plt.rc('axes', labelsize=17)
plt.rc('xtick',labelsize=17)
plt.rc('ytick',labelsize=14)

simo_score = [
[[2.6337,0.0290],[2.6623,0.0910],[3.4055,0.1526],[3.4603,0.0780],[4.4344,0.2510]],
[[4.5724,0.0447],[4.6342,0.1044],[5.2738,0.1356],[5.0364,0.1350],[6.0301,0.1875]],
[[4.5724,0.0447],[4.6342,0.1045],[5.2737,0.1357],[5.0364,0.1350],[6.0301,0.1875]],
[[4.5727,0.0476],[4.6383,0.1039],[5.2857,0.1297],[5.0399,0.1376],[6.0265,0.1960]],
[[4.5689,0.0476],[4.6331,0.1039],[5.2797,0.1290],[5.0329,0.1373],[6.0148,0.1960]],
[[4.6179,0.0594],[4.6811,0.2111],[5.7398,0.1872],[5.6670,0.2334],[6.5437,0.2477]]
]

import numpy as np
simo_score = np.array(simo_score)

print simo_score.shape

mean_simo_score = simo_score[:,:,0]/10

print mean_simo_score
x = [600,700,800,900,1000]


ax = plt.gca()
ax.spines['top'].set_visible(False) #去掉上边框
#ax.spines['bottom'].set_visible(False) #去掉下边框
#ax.spines['left'].set_visible(False) #去掉左边框
ax.spines['right'].set_visible(False) #去掉右边框fig


plt.plot(x,mean_simo_score[0],linestyle="-", linewidth=1,marker="o",markersize=10,color="black",label="SIMO")
plt.plot(x,mean_simo_score[1],linestyle="-.", linewidth=1,marker="v",markersize=10,color="red",label="OLS")
#plt.plot(x,mean_simo_score[2],linestyle="--", linewidth=1)
#plt.plot(x,mean_simo_score[3]+0.3,linestyle=":", linewidth=1)
#plt.plot(x,mean_simo_score[4],linestyle="-.", linewidth=1)
plt.plot(x,mean_simo_score[5],linestyle="-", linewidth=1,marker="*",markersize=10,color="blue",label="Huber")


plt.ylabel(r"$\epsilon_w$")
plt.xlabel("m")




plt.xticks([600,700,800,900,1000])
plt.yticks([0.25,0.35,0.45,0.55,0.65])

#plt.xticks([])
#plt.yticks([])

#plt.title(r"Fix n$=1500,\sigma=1,\alpha=0.5$")

#size = fig.get_size_inches()*fig.dpi # get fig size in pixels
#ax.set_title(r'(a)Fix n$=1500,\sigma=1,\alpha=0.5$', y=-0.35)

plt.legend()

plt.tight_layout()
plt.savefig("samples_notitle.png", format='png', bbox_inches='tight',dpi=300, pad_inches = 0)
plt.show()

# %%
m_score = [
[[2.6337,0.0290],[2.6623,0.0910],[3.4055,0.1526],[3.4603,0.0780],[4.4344,0.2510]],
[[4.5724,0.0447],[4.6342,0.1044],[5.2738,0.1356],[5.0364,0.1350],[6.0301,0.1875]],
[[4.5724,0.0447],[4.6342,0.1045],[5.2737,0.1357],[5.0364,0.1350],[6.0301,0.1875]],
[[4.5727,0.0476],[4.6383,0.1039],[5.2857,0.1297],[5.0399,0.1376],[6.0265,0.1960]],
[[4.5689,0.0476],[4.6331,0.1039],[5.2797,0.1290],[5.0329,0.1373],[6.0148,0.1960]],
[[4.6179,0.0594],[4.6811,0.2111],[5.7398,0.1872],[5.6670,0.2334],[6.5437,0.2477]]
]

n_score = [[[3.059,0.222],[2.610,0.089],[2.262,0.089],[1.827,0.1055],[1.702,0.079]],
 [[5.631,0.277],[5.027,0.074],[4.469,0.095],[4.037,0.1534],[3.784,0.039]],
 [[5.631,0.277],[5.027,0.074],[4.470,0.098],[4.038,0.1534],[3.784,0.039]],
 [[5.642,0.281],[5.033,0.070],[4.472,0.098],[4.041,0.1448],[3.789,0.042]],
 [[5.636,0.281],[5.029,0.071],[4.469,0.099],[4.039,0.1447],[3.787,0.042]],
 [[5.562,0.438],[4.816,0.149],[4.203,0.204],[3.490,0.1578],[3.103,0.138]]
]

sigma_score = [[[1.644,0.060],[1.613,0.078],[1.684,0.077],[1.585,0.063],[1.610,0.079]],
 [[3.664,0.148],[3.712,0.159],[3.837,0.142],[3.540,0.098],[3.710,0.132]],
 [[3.664,0.149],[3.712,0.160],[3.837,0.142],[3.540,0.097],[3.710,0.132]],
 [[3.666,0.148],[3.712,0.160],[3.845,0.147],[3.542,0.097],[3.714,0.132]],
 [[3.664,0.148],[3.711,0.160],[3.842,0.147],[3.542,0.097],[3.712,0.132]],
 [[2.746,0.187],[2.774,0.278],[2.965,0.206],[2.764,0.131],[2.730,0.142]],
]


alpha_score = [[[1.936,0.064],[2.751,0.113],[3.14,0.096],[3.956,0.085],[4.375,0.042]],
 [[3.781,0.071],[4.643,0.130],[4.59,0.122],[5.094,0.118],[5.154,0.146]],
 [[3.781,0.071],[4.643,0.125],[4.59,0.126],[5.119,0.136],[5.154,0.153]],
 [[3.786,0.069],[4.647,0.125],[4.59,0.126],[5.116,0.136],[5.163,0.153]],
 [[3.783,0.069],[4.645,0.125],[4.56,0.126],[5.116,0.118],[5.160,0.148]],
 [[3.630,0.087],[4.923,0.108],[5.24,0.144],[6.174,0.096],[6.259,0.131]],
]

# %%
#n_score
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('axes',titlesize=17)
plt.rc('axes', labelsize=17)
plt.rc('xtick',labelsize=17)
plt.rc('ytick',labelsize=14)

simo_score = [[[3.059,0.222],[2.610,0.089],[2.262,0.089],[1.827,0.1055],[1.702,0.079]],
 [[5.631,0.277],[5.027,0.074],[4.469,0.095],[4.037,0.1534],[3.784,0.039]],
 [[5.631,0.277],[5.027,0.074],[4.470,0.098],[4.038,0.1534],[3.784,0.039]],
 [[5.642,0.281],[5.033,0.070],[4.472,0.098],[4.041,0.1448],[3.789,0.042]],
 [[5.636,0.281],[5.029,0.071],[4.469,0.099],[4.039,0.1447],[3.787,0.042]],
 [[5.562,0.438],[4.816,0.149],[4.203,0.204],[3.490,0.1578],[3.103,0.138]]
]

import numpy as np
simo_score = np.array(simo_score)

print simo_score.shape

mean_simo_score = simo_score[:,:,0]/10

print mean_simo_score
x = [1000,1200,1400,1600,1800]


ax = plt.gca()
ax.spines['top'].set_visible(False) #去掉上边框
#ax.spines['bottom'].set_visible(False) #去掉下边框
#ax.spines['left'].set_visible(False) #去掉左边框
ax.spines['right'].set_visible(False) #去掉右边框


plt.plot(x,mean_simo_score[0],linestyle="-", linewidth=1,marker="o",markersize=10,color="black",label="SIMO")
plt.plot(x,mean_simo_score[1],linestyle="-.", linewidth=1,marker="v",markersize=10,color="red",label="OLS")
#plt.plot(x,mean_simo_score[2],linestyle="--", linewidth=1)
#plt.plot(x,mean_simo_score[3]+0.3,linestyle=":", linewidth=1)
#plt.plot(x,mean_simo_score[4],linestyle="-.", linewidth=1)
plt.plot(x,mean_simo_score[5],linestyle="-", linewidth=1,marker="*",markersize=10,color="blue",label="Huber")


plt.ylabel(r"$\epsilon_w$")
plt.xlabel("n")




#plt.xticks([1000,1200,1400,1600,1800])
plt.yticks([0.25,0.35,0.45,0.55,0.65])

plt.title(r"Fix n$=1500,\sigma=1,\alpha=0.5$")

#size = fig.get_size_inches()*fig.dpi # get fig size in pixels
ax.set_title(r'(a)Fix m$=500,\sigma=1,\alpha=0.5$', y=-0.35)

plt.legend()

plt.show()

# %%
#sigma_score
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('axes',titlesize=17)
plt.rc('axes', labelsize=17)
plt.rc('xtick',labelsize=17)
plt.rc('ytick',labelsize=14)

simo_score  = [[[1.644,0.060],[1.613,0.078],[1.684,0.077],[1.585,0.063],[1.610,0.079]],
 [[3.664,0.148],[3.712,0.159],[3.837,0.142],[3.540,0.098],[3.710,0.132]],
 [[3.664,0.149],[3.712,0.160],[3.837,0.142],[3.540,0.097],[3.710,0.132]],
 [[3.666,0.148],[3.712,0.160],[3.845,0.147],[3.542,0.097],[3.714,0.132]],
 [[3.664,0.148],[3.711,0.160],[3.842,0.147],[3.542,0.097],[3.712,0.132]],
 [[2.746,0.187],[2.774,0.278],[2.965,0.206],[2.764,0.131],[2.730,0.142]],
]

import numpy as np
simo_score = np.array(simo_score)

print simo_score.shape

mean_simo_score = simo_score[:,:,0]/10

print mean_simo_score
x = [2,3,4,5,6]


ax = plt.gca()
ax.spines['top'].set_visible(False) #去掉上边框
#ax.spines['bottom'].set_visible(False) #去掉下边框
#ax.spines['left'].set_visible(False) #去掉左边框
ax.spines['right'].set_visible(False) #去掉右边框


plt.plot(x,mean_simo_score[0],linestyle="-", linewidth=1,marker="o",markersize=10,color="black",label="SIMO")
plt.plot(x,mean_simo_score[1],linestyle="-.", linewidth=1,marker="v",markersize=10,color="red",label="OLS")
#plt.plot(x,mean_simo_score[2],linestyle="--", linewidth=1)
#plt.plot(x,mean_simo_score[3]+0.3,linestyle=":", linewidth=1)
#plt.plot(x,mean_simo_score[4],linestyle="-.", linewidth=1)
plt.plot(x,mean_simo_score[5],linestyle="-", linewidth=1,marker="*",markersize=10,color="blue",label="Huber")


plt.ylabel(r"$\epsilon_w$")
plt.xlabel(r"$\sigma$")




#plt.xticks([1000,1200,1400,1600,1800])
plt.yticks([0.15,0.20,0.25,0.30,0.35,0.40,0.45,0.50])

plt.title(r"Fix n$=1500,\sigma=1,\alpha=0.5$")

#size = fig.get_size_inches()*fig.dpi # get fig size in pixels
ax.set_title(r'(a)Fix m=500,n=1800,$\alpha=0.5$', y=-0.35)

plt.legend()

plt.show()

# %%
#alpha_score
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('axes',titlesize=17)
plt.rc('axes', labelsize=17)
plt.rc('xtick',labelsize=17)
plt.rc('ytick',labelsize=14)

simo_score =[[[1.936,0.064],[2.751,0.113],[3.14,0.096],[3.956,0.085],[4.375,0.042]],
 [[3.781,0.071],[4.643,0.130],[4.59,0.122],[5.094,0.118],[5.154,0.146]],
 [[3.781,0.071],[4.643,0.125],[4.59,0.126],[5.119,0.136],[5.154,0.153]],
 [[3.786,0.069],[4.647,0.125],[4.59,0.126],[5.116,0.136],[5.163,0.153]],
 [[3.783,0.069],[4.645,0.125],[4.56,0.126],[5.116,0.118],[5.160,0.148]],
 [[3.630,0.087],[4.923,0.108],[5.24,0.144],[6.174,0.096],[6.259,0.131]],
]

import numpy as np
simo_score = np.array(simo_score)

print simo_score.shape

mean_simo_score = simo_score[:,:,0]/10

print mean_simo_score
x = [0.6,0.7,0.8,0.9,1.0]


ax = plt.gca()
ax.spines['top'].set_visible(False) #去掉上边框
#ax.spines['bottom'].set_visible(False) #去掉下边框
#ax.spines['left'].set_visible(False) #去掉左边框
ax.spines['right'].set_visible(False) #去掉右边框


plt.plot(x,mean_simo_score[0],linestyle="-", linewidth=1,marker="o",markersize=10,color="black",label="SIMO")
plt.plot(x,mean_simo_score[1],linestyle="-.", linewidth=1,marker="v",markersize=10,color="red",label="OLS")
#plt.plot(x,mean_simo_score[2],linestyle="--", linewidth=1)
#plt.plot(x,mean_simo_score[3]+0.3,linestyle=":", linewidth=1)
#plt.plot(x,mean_simo_score[4],linestyle="-.", linewidth=1)
plt.plot(x,mean_simo_score[5],linestyle="-", linewidth=1,marker="*",markersize=10,color="blue",label="Huber")


plt.ylabel(r"$\epsilon_w$")
plt.xlabel(r"$\alpha$")




#plt.xticks([1000,1200,1400,1600,1800])
plt.yticks()

plt.title(r"Fix n$=1500,\sigma=1,\alpha=0.5$")

#size = fig.get_size_inches()*fig.dpi # get fig size in pixels
ax.set_title(r'(a)Fix m=400,n=1800,$\sigma=1$', y=-0.35)

plt.legend()

plt.show()

# %%
## result

simo_score = [
[[2.6337,0.0290],[2.6623,0.0910],[3.4055,0.1526],[3.4603,0.0780],[4.4344,0.2510]],
[[4.5724,0.0447],[4.6342,0.1044],[5.2738,0.1356],[5.0364,0.1350],[6.0301,0.1875]],
[[4.5724,0.0447],[4.6342,0.1045],[5.2737,0.1357],[5.0364,0.1350],[6.0301,0.1875]],
[[4.5727,0.0476],[4.6383,0.1039],[5.2857,0.1297],[5.0399,0.1376],[6.0265,0.1960]],
[[4.5689,0.0476],[4.6331,0.1039],[5.2797,0.1290],[5.0329,0.1373],[6.0148,0.1960]],
[[4.6179,0.0594],[4.6811,0.2111],[5.7398,0.1872],[5.6670,0.2334],[6.5437,0.2477]]
]
import numpy as np
simo_score = np.array(simo_score)
print simo_score.shape
mean_simo_score = simo_score[:,:,0]/10
print mean_simo_score
data = mean_simo_score

import matplotlib.pyplot as plt
plt.rc('axes',titlesize=25)
plt.rc('axes', labelsize=25)
plt.rc('xtick',labelsize=17)
plt.rc('ytick',labelsize=14)
plt.figure(figsize=(24, 4.5))


plt.subplot(141)
x = [600,700,800,900,1000]
y = [0,1,5]
title=r'(a) Fix n=1500,$\sigma$=1,$\alpha$=0.5'
yticks = [0.25,0.35,0.45,0.55,0.65,0.75]
#istitle=False
#name = "sample_notitle.png"
istitle=True
name = "samples.eps"
ax = plt.gca()
ax.spines['top'].set_visible(False) #去掉上边框
#ax.spines['bottom'].set_visible(False) #去掉下边框
#ax.spines['left'].set_visible(False) #去掉左边框
ax.spines['right'].set_visible(False) #去掉右边框
plt.plot(x,data[0],linestyle="-", linewidth=1,marker="o",markersize=10,color="black",label="SIMO")
plt.plot(x,data[1],linestyle="-.", linewidth=1,marker="v",markersize=10,color="red",label="OLS")
#plt.plot(x,mean_simo_score[2],linestyle="--", linewidth=1)
#plt.plot(x,mean_simo_score[3]+0.3,linestyle=":", linewidth=1)
#plt.plot(x,mean_simo_score[4],linestyle="-.", linewidth=1)
plt.plot(x,data[5],linestyle="-", linewidth=1,marker="*",markersize=10,color="blue",label="Huber")
plt.ylabel(r"$\epsilon_w$")
plt.xlabel("m")

plt.xticks()
plt.yticks(yticks)

#plt.xticks([])
#plt.yticks([])

#plt.title(r"Fix n$=1500,\sigma=1,\alpha=0.5$")

#size = fig.get_size_inches()*fig.dpi # get fig size in pixels

ax.tick_params(direction='in')
plt.legend(fontsize=20)
plt.tight_layout()
ax.set_title(r'(a) Fix n=1500,$\sigma$=1,$\alpha$=0.5', y=-0.35,fontweight='bold')


plt.subplot(142)
x = [600,700,800,900,1000]
y = [0,1,5]
title=r'(a) Fix n=1500,$\sigma$=1,$\alpha$=0.5'
yticks = [0.25,0.35,0.45,0.55,0.65,0.75]
#istitle=False
#name = "sample_notitle.png"
istitle=True
name = "samples.eps"
ax = plt.gca()
ax.spines['top'].set_visible(False) #去掉上边框
#ax.spines['bottom'].set_visible(False) #去掉下边框
#ax.spines['left'].set_visible(False) #去掉左边框
ax.spines['right'].set_visible(False) #去掉右边框
plt.plot(x,data[0],linestyle="-", linewidth=1,marker="o",markersize=10,color="black",label="SIMO")
plt.plot(x,data[1],linestyle="-.", linewidth=1,marker="v",markersize=10,color="red",label="OLS")
#plt.plot(x,mean_simo_score[2],linestyle="--", linewidth=1)
#plt.plot(x,mean_simo_score[3]+0.3,linestyle=":", linewidth=1)
#plt.plot(x,mean_simo_score[4],linestyle="-.", linewidth=1)
plt.plot(x,data[5],linestyle="-", linewidth=1,marker="*",markersize=10,color="blue",label="Huber")
plt.ylabel(r"$\epsilon_w$")
plt.xlabel("m")

plt.xticks()
plt.yticks(yticks)

#plt.xticks([])
#plt.yticks([])

#plt.title(r"Fix n$=1500,\sigma=1,\alpha=0.5$")

#size = fig.get_size_inches()*fig.dpi # get fig size in pixels

ax.tick_params(direction='in')
plt.legend(fontsize=20)
plt.tight_layout()
ax.set_title(r'(a) Fix n=1500,$\sigma$=1,$\alpha$=0.5', y=-0.35,fontweight='bold')



plt.subplot(143)
x = [600,700,800,900,1000]
y = [0,1,5]
title=r'(a) Fix n=1500,$\sigma$=1,$\alpha$=0.5'
yticks = [0.25,0.35,0.45,0.55,0.65,0.75]
#istitle=False
#name = "sample_notitle.png"
istitle=True
name = "samples.eps"
ax = plt.gca()
ax.spines['top'].set_visible(False) #去掉上边框
#ax.spines['bottom'].set_visible(False) #去掉下边框
#ax.spines['left'].set_visible(False) #去掉左边框
ax.spines['right'].set_visible(False) #去掉右边框
plt.plot(x,data[0],linestyle="-", linewidth=1,marker="o",markersize=10,color="black",label="SIMO")
plt.plot(x,data[1],linestyle="-.", linewidth=1,marker="v",markersize=10,color="red",label="OLS")
#plt.plot(x,mean_simo_score[2],linestyle="--", linewidth=1)
#plt.plot(x,mean_simo_score[3]+0.3,linestyle=":", linewidth=1)
#plt.plot(x,mean_simo_score[4],linestyle="-.", linewidth=1)
plt.plot(x,data[5],linestyle="-", linewidth=1,marker="*",markersize=10,color="blue",label="Huber")
plt.ylabel(r"$\epsilon_w$")
plt.xlabel("m")

plt.xticks()
plt.yticks(yticks)

#plt.xticks([])
#plt.yticks([])

#plt.title(r"Fix n$=1500,\sigma=1,\alpha=0.5$")

#size = fig.get_size_inches()*fig.dpi # get fig size in pixels

ax.tick_params(direction='in')
plt.legend(fontsize=20)
plt.tight_layout()
ax.set_title(r'(a) Fix n=1500,$\sigma$=1,$\alpha$=0.5', y=-0.35,fontweight='bold')



plt.subplot(144)
x = [600,700,800,900,1000]
y = [0,1,5]
title=r'(a) Fix n=1500,$\sigma$=1,$\alpha$=0.5'
yticks = [0.25,0.35,0.45,0.55,0.65,0.75]
#istitle=False
#name = "sample_notitle.png"
istitle=True
name = "samples.eps"
ax = plt.gca()
ax.spines['top'].set_visible(False) #去掉上边框
#ax.spines['bottom'].set_visible(False) #去掉下边框
#ax.spines['left'].set_visible(False) #去掉左边框
ax.spines['right'].set_visible(False) #去掉右边框
plt.plot(x,data[0],linestyle="-", linewidth=1,marker="o",markersize=10,color="black",label="SIMO")
plt.plot(x,data[1],linestyle="-.", linewidth=1,marker="v",markersize=10,color="red",label="OLS")
#plt.plot(x,mean_simo_score[2],linestyle="--", linewidth=1)
#plt.plot(x,mean_simo_score[3]+0.3,linestyle=":", linewidth=1)
#plt.plot(x,mean_simo_score[4],linestyle="-.", linewidth=1)
plt.plot(x,data[5],linestyle="-", linewidth=1,marker="*",markersize=10,color="blue",label="Huber")
plt.ylabel(r"$\epsilon_w$")
plt.xlabel("m")

plt.xticks()
plt.yticks(yticks)

#plt.xticks([])
#plt.yticks([])

#plt.title(r"Fix n$=1500,\sigma=1,\alpha=0.5$")

#size = fig.get_size_inches()*fig.dpi # get fig size in pixels

ax.tick_params(direction='in')
plt.legend(fontsize=20)
plt.tight_layout()
ax.set_title(r'(a) Fix n=1500,$\sigma$=1,$\alpha$=0.5', y=-0.35,fontweight='bold')



plt.savefig("samples.eps", format='eps', bbox_inches='tight', pad_inches = 0)
plt.show()
